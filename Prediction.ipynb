# %%
import pandas as pd

# %%
df=pd.read_csv('Dataset/car_data.csv')

# %%
df.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# ...

# %%
df.drop(['Car_Name'],axis=1,inplace=True)

# %%
df.isnull().any()
# Out:
# Year             False
# Selling_Price    False
# Present_Price    False
# Kms_Driven       False
# Fuel_Type        False
# Seller_Type      False
# Transmission     False
# Owner            False
# dtype: bool

# %%
def used_duration(text):
    year=int(text)
    year=2020-year
    return year

# %%
df['Year']=df['Year'].apply(used_duration)

# %%
df.head(10)
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     6           3.35           5.59       27000    Petrol      Dealer
# 1     7           4.75           9.54       43000    Diesel      Dealer
# 2     3           7.25           9.85        6900    Petrol      Dealer
# 3     9           2.85           4.15        5200    Petrol      Dealer
# 4     6           4.60           6.87       42450    Diesel      Dealer
# 5     2           9.25           9.83        2071    Diesel      Dealer
# 6     5           6.75           8.12       18796    Petrol      Dealer
# 7     5           6.50           8.61       33429    Diesel      Dealer
# 8     4           8.75           8.89       20273    Diesel      Dealer
# 9     5           7.45           8.92       42367    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0
# 5       Manual      0
# ...

# %%
df=pd.get_dummies(df, columns=['Fuel_Type'],drop_first=True)
df=pd.get_dummies(df, columns=['Seller_Type'],drop_first=True)
df=pd.get_dummies(df, columns=['Transmission'],drop_first=True)
df=pd.get_dummies(df, columns=['Owner'],drop_first=True)

# %%
df.head(10)
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type_Diesel  \
# 0     6           3.35           5.59       27000                 0
# 1     7           4.75           9.54       43000                 1
# 2     3           7.25           9.85        6900                 0
# 3     9           2.85           4.15        5200                 0
# 4     6           4.60           6.87       42450                 1
# 5     2           9.25           9.83        2071                 1
# 6     5           6.75           8.12       18796                 0
# 7     5           6.50           8.61       33429                 1
# 8     4           8.75           8.89       20273                 1
# 9     5           7.45           8.92       42367                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual  Owner_1  \
# 0                 1                       0                    1        0
# ...

# %%
X=df.iloc[:,[0,2,3,4,5,6,7,8,9]]
y=df.iloc[:,[1]]

# %%
from sklearn.ensemble import ExtraTreesRegressor
regressor=ExtraTreesRegressor()
regressor.fit(X,y)
# Out:
# C:\Users\Alee\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# ExtraTreesRegressor()

# %%
regressor.predict([[6,5.59,27000,0,1,0,1,1,0]])
# Out:
# array([3.35])

# %%
import pickle

file = open('Model/Prediction', 'wb')
pickle.dump(regressor, file)
file.close()

# %%
import pickle
file = open('Model/Prediction', 'rb')
regressor = pickle.load(file)
file.close()

# %%
regressor.predict([[5,8.92,42367,1,0,0,1,0,0]])
# Out:
# array([7.45])
